# %%
using CSV
using DataFrames
using DataFramesMeta

# %%
dirs = pwd() * "/monthly";
dirs = readdir(dirs)
# Out:
# 12-element Array{String,1}:
#  "2017-09"
#  "2017-10"
#  "2017-11"
#  "2017-12"
#  "2018-01"
#  "2018-02"
#  "2018-03"
#  "2018-04"
#  "2018-05"
#  "2018-06"
#  "2018-07"
#  "2018-08"

# %%
# yay array comprehension!
dirsfull = ["monthly/" * s * "/361420861_T_ONTIME_REPORTING.csv" for s in dirs];

# %%
#for i in dirsfull
#    data = CSV.read(i, append=true);
#end

# %%
# Okay for whatever reason the read-and-append function in CSV went MIA/stopped working so lets call Python's pandas to help instead
#using Pkg
#ENV["PYTHON"] = "datascience"
#Pkg.build("PyCall")
#using PyCall
#@pyimport pandas as pd
#data = pd.concat((pd.read_csv(i) for i in dirsfull))
#display(data)
#display(typeof(data))
#display(size(data))
# Out:
# PyObject         YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE OP_UNIQUE_CARRIER  \
# 0       2017      9             5            2  2017-09-05                UA
# 1       2017      9             5            2  2017-09-05                UA
# 2       2017      9             5            2  2017-09-05                UA
# 3       2017      9             5            2  2017-09-05                UA
# 4       2017      9             5            2  2017-09-05                UA
# 5       2017      9             5            2  2017-09-05                UA
# 6       2017      9             5            2  2017-09-05                UA
# 7       2017      9             5            2  2017-09-05                UA
# 8       2017      9             5            2  2017-09-05                UA
# 9       2017      9             5            2  2017-09-05                UA
# 10      2017      9             5            2  2017-09-05                UA
# ...

# %%
using Pandas

# %%
data = concat((read_csv(i) for i in dirsfull));
display(data)
display(typeof(data))
display(size(data))
# Out:
#         YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE OP_UNIQUE_CARRIER  \
# 0       2017      9             5            2  2017-09-05                UA
# 1       2017      9             5            2  2017-09-05                UA
# 2       2017      9             5            2  2017-09-05                UA
# 3       2017      9             5            2  2017-09-05                UA
# 4       2017      9             5            2  2017-09-05                UA
# 5       2017      9             5            2  2017-09-05                UA
# 6       2017      9             5            2  2017-09-05                UA
# 7       2017      9             5            2  2017-09-05                UA
# 8       2017      9             5            2  2017-09-05                UA
# 9       2017      9             5            2  2017-09-05                UA
# 10      2017      9             5            2  2017-09-05                UA
# ...

# %% [markdown]
# Top 30 largest airports from here: https://en.wikipedia.org/wiki/List_of_the_busiest_airports_in_the_United_States

# %%
top30 = ["ATL","LAX","ORD","DFW","DEN","JFK","SFO","LAS","SEA","CLT",
         "EWR","MCO","PHX","MIA","IAH","BOS","MSP","DTW","FLL","PHL",
         "LGA","BWI","SLC","DCA","IAD","SAN","MDW","TPA","HNL","PDX"];

# %%
#isin(data[:ORIGIN],top30)
datatop30 = data[isin(data[:ORIGIN],top30)]

#dftop30 = df[df['ORIGIN'].isin(top30)]
#datatop30 = df[df['ORIGIN'].isin(top30)]
# Out:
#         YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE OP_UNIQUE_CARRIER  \
# 1       2017      9             5            2  2017-09-05                UA
# 2       2017      9             5            2  2017-09-05                UA
# 3       2017      9             5            2  2017-09-05                UA
# 4       2017      9             5            2  2017-09-05                UA
# 5       2017      9             5            2  2017-09-05                UA
# 9       2017      9             5            2  2017-09-05                UA
# 10      2017      9             5            2  2017-09-05                UA
# 12      2017      9             5            2  2017-09-05                UA
# 13      2017      9             5            2  2017-09-05                UA
# 14      2017      9             5            2  2017-09-05                UA
# 15      2017      9             5            2  2017-09-05                UA
# ...

# %%
data = DataFrames.DataFrame(data);
display(typeof(data))
